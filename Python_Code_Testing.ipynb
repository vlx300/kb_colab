# %% [markdown]
# <a href="https://colab.research.google.com/github/vlx300/kb_colab/blob/master/Python_Code_Testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Testing CODE in Python**
# ![alt text](data:image/jpeg;base64,...)
